# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/songsooyeoun/Desktop/git_test/streamlit/project1/data/seoul_real_estate.csv')
data
# Out:
#        RCPT_YR  CGG_CD CGG_NM  STDG_CD STDG_NM  LOTNO_SE LOTNO_SE_NM     MNO  \
# 0         2025   11230   동대문구    10400     전농동       1.0          대지   690.0
# 1         2025   11230   동대문구    10500    답십리동       1.0          대지  1003.0
# 2         2025   11740    강동구    10900     천호동       NaN         NaN     NaN
# 3         2025   11545    금천구    10200     독산동       1.0          대지   180.0
# 4         2025   11740    강동구    10900     천호동       NaN         NaN     NaN
# ...        ...     ...    ...      ...     ...       ...         ...     ...
# 10995     2025   11545    금천구    10100     가산동       1.0          대지   139.0
# 10996     2025   11590    동작구    10200     상도동       1.0          대지   531.0
# 10997     2025   11470    양천구    10200      목동       1.0          대지   911.0
# 10998     2025   11680    강남구    10500     삼성동       1.0          대지   144.0
# 10999     2025   11170    용산구    12000     도원동       1.0          대지    23.0
#
#         SNO          BLDG_NM  ... THING_AMT  ARCH_AREA  LAND_AREA   FLR  \
# 0       0.0          래미안크레시티  ...    142000     84.960     0.0000  16.0
# 1       0.0            래미안위브  ...    117000     59.970     0.0000  12.0
# 2       NaN              NaN  ...     99630    197.100   103.0000   0.0
# 3      36.0         (180-36)  ...     26000     94.960    45.0000   3.0
# 4       NaN              NaN  ...    136037    192.000   149.0000   0.0
# ...     ...              ...  ...       ...        ...        ...   ...
# 10995   3.0         램킨푸르지오시티  ...     12000     19.960    28.5945  13.0
# 10996   0.0   힐스테이트 상도 센트럴파크  ...    145000     84.609     0.0000   4.0
# 10997   0.0          목동신시가지6  ...    189000     65.100     0.0000   3.0
# 10998   1.0  삼성동 현대위버포레 오피스텔  ...     53500     29.080    43.8300   5.0
# 10999   0.0            삼성래미안  ...    160000    114.990     0.0000  12.0
#
#        RGHT_SE RTRCN_DAY  ARCH_YR  BLDG_USG DCLR_SE OPBIZ_RESTAGNT_SGG_NM
# 0          NaN       NaN   2014.0       아파트    중개거래               서울 동대문구
# 1          NaN       NaN   2014.0       아파트    중개거래               서울 동대문구
# 2          NaN       NaN   1995.0     단독다가구     직거래                   NaN
# 3          NaN       NaN   1998.0     연립다세대     직거래                   NaN
# 4          NaN       NaN   1983.0     단독다가구     직거래                   NaN
# ...        ...       ...      ...       ...     ...                   ...
# 10995      NaN       NaN   2013.0      오피스텔    중개거래                서울 금천구
# 10996      NaN       NaN   2012.0       아파트    중개거래                서울 동작구
# 10997      NaN       NaN   1986.0       아파트    중개거래                서울 양천구
# 10998      NaN       NaN   2022.0      오피스텔    중개거래                서울 강남구
# 10999      NaN       NaN   2001.0       아파트    중개거래                서울 용산구
#
# [11000 rows x 21 columns]

# %%
data["CTRT_DAY"] = pd.to_datetime(data["CTRT_DAY"].astype(str), format="%Y-%m-%d")
data["month"] = data["CTRT_DAY"].dt.month
data["month"].unique()
# Out:
# array([3, 2], dtype=int32)

# %%
print(data["CTRT_DAY"].min())
print(data["CTRT_DAY"].max())
# Out:
# 2025-02-11 00:00:00
# 2025-03-22 00:00:00

# %%
import matplotlib.pyplot as plt

# Set font to "NanumGothic"
plt.rcParams['font.family'] = "NanumGothic"

# Create a sample plot to check if the font is applied
plt.figure(figsize=(6, 4))
plt.plot([1, 2, 3], [1, 2, 3], label='Line 1')
plt.title('테스트 제목')  # Korean title to check font
plt.xlabel('X축')  # Korean label to check font
plt.ylabel('Y축')  # Korean label to check font
plt.legend()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
